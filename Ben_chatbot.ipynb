# %% [markdown]
# <a href="https://colab.research.google.com/github/mmsamiei/AI_projects/blob/master/Ben_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext.datasets import TranslationDataset, Multi30k
from torchtext.data import Field, BucketIterator

import spacy

import random
import math
import os
import time

# %%
SEED = 1

random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
#spacy_de = spacy.load('de')
spacy_en = spacy.load('en')

# %%
def tokenize_de(text):
    """
    Tokenizes German text from a string into a list of strings
    """
    return [tok.text for tok in spacy_de.tokenizer(text)]

def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
SRC = Field(tokenize=tokenize_en, init_token='<sos>', eos_token='<eos>', lower=True, batch_first=True)
TRG = Field(tokenize=tokenize_en, init_token='<sos>', eos_token='<eos>', lower=True, batch_first=True)

# %%
#train_data, valid_data, test_data = Multi30k.splits(exts=('.de', '.en'), fields=(SRC, TRG))

# %%
from torchtext.data import TabularDataset, interleave_keys

train_dataset = TabularDataset(path="./formatted_movie_lines.txt", format="CSV",
                               fields=[("query", SRC),("response", TRG)],
                               csv_reader_params={"delimiter":'\t'})

# %%
SRC.build_vocab(train_dataset, min_freq=2)
TRG.build_vocab(train_dataset, min_freq=2)

# %%
len(train_dataset)
# Out:
# 221282

# %%
train_backup = train_dataset.examples

# %%
##############

# %%
temp = []
print(len(temp))
for i, example in enumerate(train_backup):
  if( (len(example.query) < 6) and (len(example.response) < 6) ):
    temp.append(example)
print(len(temp))
# Out:
# 0
# 17631

# %%
train_dataset.examples = temp

# %%
len(train_dataset)
# Out:
# 17631

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
BATCH_SIZE = 256

train_iterator = BucketIterator(train_dataset,
     batch_size=BATCH_SIZE,
     sort_key=lambda x: interleave_keys(len(x.query), len(x.response)),
     sort = True,
     device=device)

# %%
len(list(iter(train_iterator)))
# Out:
# 69

# %%
for batch in iter(train_iterator):
  print(batch.query.shape)
# Out:
# torch.Size([256, 5])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 4])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 5])
# torch.Size([256, 7])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 6])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([256, 7])
# torch.Size([223, 7])

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, hid_dim, n_layers, n_heads, pf_dim, encoder_layer, self_attention, positionwise_feedforward, dropout, device):
        super().__init__()

        self.input_dim = input_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.n_heads = n_heads
        self.pf_dim = pf_dim
        self.encoder_layer = encoder_layer
        self.self_attention = self_attention
        self.positionwise_feedforward = positionwise_feedforward
        self.dropout = dropout
        self.device = device
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        self.pos_embedding = nn.Embedding(1000, hid_dim)
        
        self.layers = nn.ModuleList([encoder_layer(hid_dim, n_heads, pf_dim, self_attention, positionwise_feedforward, dropout, device) 
                                     for _ in range(n_layers)])
        
        self.do = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src sent len]
        #src_mask = [batch size, src sent len]
        
        pos = torch.arange(0, src.shape[1]).unsqueeze(0).repeat(src.shape[0], 1).to(self.device)
        
        src = self.do((self.tok_embedding(src) * self.scale) + self.pos_embedding(pos))
        
        #src = [batch size, src sent len, hid dim]
        
        for layer in self.layers:
            src = layer(src, src_mask)
            
        return src

# %%
class EncoderLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, pf_dim, self_attention, positionwise_feedforward, dropout, device):
        super().__init__()
        
        self.ln = nn.LayerNorm(hid_dim)
        self.sa = self_attention(hid_dim, n_heads, dropout, device)
        self.pf = positionwise_feedforward(hid_dim, pf_dim, dropout)
        self.do = nn.Dropout(dropout)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src sent len, hid dim]
        #src_mask = [batch size, src sent len]
        
        src = self.ln(src + self.do(self.sa(src, src, src, src_mask)))
        
        src = self.ln(src + self.do(self.pf(src)))
        
        return src

# %%
class SelfAttention(nn.Module):
    def __init__(self, hid_dim, n_heads, dropout, device):
        super().__init__()
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        
        assert hid_dim % n_heads == 0
        
        self.w_q = nn.Linear(hid_dim, hid_dim)
        self.w_k = nn.Linear(hid_dim, hid_dim)
        self.w_v = nn.Linear(hid_dim, hid_dim)
        
        self.fc = nn.Linear(hid_dim, hid_dim)
        
        self.do = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim // n_heads])).to(device)
        
    def forward(self, query, key, value, mask=None):
        
        bsz = query.shape[0]
        
        #query = key = value [batch size, sent len, hid dim]
                
        Q = self.w_q(query)
        K = self.w_k(key)
        V = self.w_v(value)
        
        #Q, K, V = [batch size, sent len, hid dim]
        
        Q = Q.view(bsz, -1, self.n_heads, self.hid_dim // self.n_heads).permute(0, 2, 1, 3)
        K = K.view(bsz, -1, self.n_heads, self.hid_dim // self.n_heads).permute(0, 2, 1, 3)
        V = V.view(bsz, -1, self.n_heads, self.hid_dim // self.n_heads).permute(0, 2, 1, 3)
        
        #Q, K, V = [batch size, n heads, sent len, hid dim // n heads]
        
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        
        #energy = [batch size, n heads, sent len, sent len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = self.do(torch.softmax(energy, dim=-1))
        
        #attention = [batch size, n heads, sent len, sent len]
        
        x = torch.matmul(attention, V)
        
        #x = [batch size, n heads, sent len, hid dim // n heads]
        
        x = x.permute(0, 2, 1, 3).contiguous()
        
        #x = [batch size, sent len, n heads, hid dim // n heads]
        
        x = x.view(bsz, -1, self.n_heads * (self.hid_dim // self.n_heads))
        
        #x = [batch size, src sent len, hid dim]
        
        x = self.fc(x)
        
        #x = [batch size, sent len, hid dim]
        
        return x

# %%
class PositionwiseFeedforward(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.hid_dim = hid_dim
        self.pf_dim = pf_dim
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.do = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, sent len, hid dim]
        
        x = self.do(torch.relu(self.fc_1(x)))
        
        #x = [batch size, sent len, pf dim]
        
        x = self.fc_2(x)
        
        #x = [batch size, sent len, hid dim]
        
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, hid_dim, n_layers, n_heads, pf_dim, decoder_layer, self_attention, positionwise_feedforward, dropout, device):
        super().__init__()
        
        self.output_dim = output_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.n_heads = n_heads
        self.pf_dim = pf_dim
        self.decoder_layer = decoder_layer
        self.self_attention = self_attention
        self.positionwise_feedforward = positionwise_feedforward
        self.dropout = dropout
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(1000, hid_dim)
        
        self.layers = nn.ModuleList([decoder_layer(hid_dim, n_heads, pf_dim, self_attention, positionwise_feedforward, dropout, device)
                                     for _ in range(n_layers)])
        
        self.fc = nn.Linear(hid_dim, output_dim)
        
        self.do = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, src, trg_mask, src_mask):
        
        #trg = [batch_size, trg sent len]
        #src = [batch_size, src sent len]
        #trg_mask = [batch size, trg sent len]
        #src_mask = [batch size, src sent len]
        
        pos = torch.arange(0, trg.shape[1]).unsqueeze(0).repeat(trg.shape[0], 1).to(self.device)
                
        trg = self.do((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
        
        #trg = [batch size, trg sent len, hid dim]
        
        for layer in self.layers:
            trg = layer(trg, src, trg_mask, src_mask)
            
        return self.fc(trg)

# %%
class DecoderLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, pf_dim, self_attention, positionwise_feedforward, dropout, device):
        super().__init__()
        
        self.ln = nn.LayerNorm(hid_dim)
        self.sa = self_attention(hid_dim, n_heads, dropout, device)
        self.ea = self_attention(hid_dim, n_heads, dropout, device)
        self.pf = positionwise_feedforward(hid_dim, pf_dim, dropout)
        self.do = nn.Dropout(dropout)
        
    def forward(self, trg, src, trg_mask, src_mask):
        
        #trg = [batch size, trg sent len, hid dim]
        #src = [batch size, src sent len, hid dim]
        #trg_mask = [batch size, trg sent len]
        #src_mask = [batch size, src sent len]
                
        trg = self.ln(trg + self.do(self.sa(trg, trg, trg, trg_mask)))
                
        trg = self.ln(trg + self.do(self.ea(trg, src, src, src_mask)))
        
        trg = self.ln(trg + self.do(self.pf(trg)))
        
        return trg

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, sos_idx, pad_idx, device, maxlen=50):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.sos_idx = sos_idx
        self.pad_idx = pad_idx
        self.device = device
        self.maxlen = maxlen
        
    def make_masks(self, src, trg):
        
        #src = [batch size, src sent len]
        #trg = [batch size, trg sent len]
        
        src_mask = (src != self.pad_idx).unsqueeze(1).unsqueeze(2)
        
        trg_pad_mask = (trg != self.pad_idx).unsqueeze(1).unsqueeze(3)
        
        #src_mask = [batch size, 1, 1, src sent len]
        #trg_pad_mask = [batch size, 1, trg sent len, 1]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device=self.device)).bool()
                        
        #trg_sub_mask = [trg sent len, trg sent len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg sent len, trg sent len]
        
        return src_mask, trg_mask
    
    def forward(self, src, trg):
        
        #src = [batch size, src sent len]
        #trg = [batch size, trg sent len]
                
        src_mask, trg_mask = self.make_masks(src, trg)
        
        enc_src = self.encoder(src, src_mask)
        
        #enc_src = [batch size, src sent len, hid dim]
                
        out = self.decoder(trg, enc_src, trg_mask, src_mask)
        
        #out = [batch size, trg sent len, output dim]
        
        return out
    
    def translate_sequences(self, src):
        #src = [batch size, src sent len]
        
        batch_size, src_len = src.shape
        trg = src.new_full((batch_size, 1), self.sos_idx)
        #trg = [batch size, 1]
        src_mask, trg_mask = self.make_masks(src, trg)
        
        enc_src = self.encoder(src, src_mask)
        
        #enc_src = [batch size, src sent len, hid dim]
        
        translation_step = 0
        while translation_step < self.maxlen:
            out = self.decoder(trg, enc_src, trg_mask, src_mask)
            # out - [batch size, trg sent len, output dim]
            out = torch.argmax(out[:, -1], dim=1) # batch size
            out = out.unsqueeze(1) # batch size, 1
            trg = torch.cat((trg, out), dim=1)
            # trg - [batch size, trg sent len]
            src_mask, trg_mask = self.make_masks(src, trg)
            translation_step += 1
        return trg

# %%
input_dim = len(SRC.vocab)
hid_dim = 512
n_layers = 6
n_heads = 8
pf_dim = 2048
dropout = 0.1

enc = Encoder(input_dim, hid_dim, n_layers, n_heads, pf_dim, EncoderLayer, SelfAttention, PositionwiseFeedforward, dropout, device)

# %%
output_dim = len(TRG.vocab)
hid_dim = 512
n_layers = 6
n_heads = 8
pf_dim = 2048
dropout = 0.1

dec = Decoder(output_dim, hid_dim, n_layers, n_heads, pf_dim, DecoderLayer, SelfAttention, PositionwiseFeedforward, dropout, device)

# %%
pad_idx = SRC.vocab.stoi['<pad>']
sos_idx = SRC.vocab.stoi['<sos>']

model = Seq2Seq(enc, dec, sos_idx, pad_idx, device).to(device)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 87,693,463 trainable parameters

# %%
for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

# %%
class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        return self.factor * \
            (self.model_size ** (-0.5) *
            min(step ** (-0.5), step * self.warmup ** (-1.5)))
    
    def zero_grad(self):
        self.optimizer.zero_grad()

# %%
optimizer = NoamOpt(hid_dim, 1, 2000,
            torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))

# %%
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.query
        trg = batch.response
        
        #if(i%100==1):
        #  print("src shape {}->batch {}: {}".format(src.shape,i, loss))

        optimizer.zero_grad()
        
        output = model(src, trg[:,:-1])
                
        #output = [batch size, trg sent len - 1, output dim]
        #trg = [batch size, trg sent len]
            
        output = output.contiguous().view(-1, output.shape[-1])
        trg = trg[:,1:].contiguous().view(-1)
                
        #output = [batch size * trg sent len - 1, output dim]
        #trg = [batch size * trg sent len - 1]
            
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output = model(src, trg[:,:-1])
            
            #output = [batch size, trg sent len - 1, output dim]
            #trg = [batch size, trg sent len]
            
            output = output.contiguous().view(-1, output.shape[-1])
            trg = trg[:,1:].contiguous().view(-1)
            
            #output = [batch size * trg sent len - 1, output dim]
            #trg = [batch size * trg sent len - 1]
            
            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
N_EPOCHS = 300
CLIP = 300

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    #valid_loss = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    # if valid_loss < best_valid_loss:
    #     best_valid_loss = valid_loss
    #     torch.save(model.state_dict(), 'tut6-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    #print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 01 | Time: 0m 30s
# 	Train Loss: 3.858 | Train PPL:  47.372
# Epoch: 02 | Time: 0m 30s
# 	Train Loss: 3.274 | Train PPL:  26.415
# Epoch: 03 | Time: 0m 30s
# 	Train Loss: 2.924 | Train PPL:  18.620
# Epoch: 04 | Time: 0m 30s
# 	Train Loss: 2.627 | Train PPL:  13.832
# Epoch: 05 | Time: 0m 30s
# 	Train Loss: 2.425 | Train PPL:  11.306
# Epoch: 06 | Time: 0m 30s
# 	Train Loss: 2.291 | Train PPL:   9.884
# Epoch: 07 | Time: 0m 30s
# 	Train Loss: 2.172 | Train PPL:   8.775
# Epoch: 08 | Time: 0m 30s
# 	Train Loss: 2.085 | Train PPL:   8.042
# Epoch: 09 | Time: 0m 30s
# 	Train Loss: 2.019 | Train PPL:   7.529
# Epoch: 10 | Time: 0m 30s
# 	Train Loss: 1.937 | Train PPL:   6.937
# Epoch: 11 | Time: 0m 30s
# 	Train Loss: 1.875 | Train PPL:   6.519
# Epoch: 12 | Time: 0m 30s
# 	Train Loss: 1.824 | Train PPL:   6.196
# Epoch: 13 | Time: 0m 30s
# 	Train Loss: 1.775 | Train PPL:   5.898
# Epoch: 14 | Time: 0m 30s
# 	Train Loss: 1.747 | Train PPL:   5.738
# Epoch: 15 | Time: 0m 29s
# 	Train Loss: 1.706 | Train PPL:   5.505
# Epoch: 16 | Time: 0m 30s
# 	Train Loss: 1.637 | Train PPL:   5.139
# Epoch: 17 | Time: 0m 30s
# 	Train Loss: 1.616 | Train PPL:   5.033
# Epoch: 18 | Time: 0m 30s
# 	Train Loss: 1.572 | Train PPL:   4.818
# Epoch: 19 | Time: 0m 30s
# 	Train Loss: 1.572 | Train PPL:   4.818
# Epoch: 20 | Time: 0m 30s
# 	Train Loss: 1.599 | Train PPL:   4.946
# Epoch: 21 | Time: 0m 29s
# 	Train Loss: 1.509 | Train PPL:   4.522
# Epoch: 22 | Time: 0m 30s
# 	Train Loss: 1.491 | Train PPL:   4.443
# Epoch: 23 | Time: 0m 30s
# 	Train Loss: 1.515 | Train PPL:   4.550
# Epoch: 24 | Time: 0m 30s
# 	Train Loss: 1.552 | Train PPL:   4.723
# Epoch: 25 | Time: 0m 30s
# 	Train Loss: 1.550 | Train PPL:   4.711
# Epoch: 26 | Time: 0m 29s
# 	Train Loss: 1.578 | Train PPL:   4.846
# Epoch: 27 | Time: 0m 29s
# 	Train Loss: 1.573 | Train PPL:   4.823
# Epoch: 28 | Time: 0m 29s
# 	Train Loss: 1.634 | Train PPL:   5.125
# Epoch: 29 | Time: 0m 30s
# 	Train Loss: 1.575 | Train PPL:   4.829
# Epoch: 30 | Time: 0m 30s
# 	Train Loss: 1.621 | Train PPL:   5.057
# Epoch: 31 | Time: 0m 30s
# 	Train Loss: 1.643 | Train PPL:   5.172
# Epoch: 32 | Time: 0m 30s
# 	Train Loss: 1.604 | Train PPL:   4.974
# Epoch: 33 | Time: 0m 30s
# 	Train Loss: 1.529 | Train PPL:   4.614
# Epoch: 34 | Time: 0m 30s
# 	Train Loss: 1.619 | Train PPL:   5.046
# Epoch: 35 | Time: 0m 30s
# 	Train Loss: 1.599 | Train PPL:   4.950
# Epoch: 36 | Time: 0m 30s
# 	Train Loss: 1.560 | Train PPL:   4.758
# Epoch: 37 | Time: 0m 29s
# 	Train Loss: 1.514 | Train PPL:   4.545
# Epoch: 38 | Time: 0m 29s
# 	Train Loss: 1.551 | Train PPL:   4.714
# Epoch: 39 | Time: 0m 29s
# 	Train Loss: 1.538 | Train PPL:   4.653
# Epoch: 40 | Time: 0m 30s
# 	Train Loss: 1.482 | Train PPL:   4.403
# Epoch: 41 | Time: 0m 30s
# 	Train Loss: 1.443 | Train PPL:   4.231
# Epoch: 42 | Time: 0m 30s
# 	Train Loss: 1.469 | Train PPL:   4.344
# Epoch: 43 | Time: 0m 30s
# 	Train Loss: 1.427 | Train PPL:   4.167
# Epoch: 44 | Time: 0m 30s
# 	Train Loss: 1.434 | Train PPL:   4.195
# Epoch: 45 | Time: 0m 30s
# 	Train Loss: 1.418 | Train PPL:   4.127
# Epoch: 46 | Time: 0m 30s
# 	Train Loss: 1.438 | Train PPL:   4.211
# Epoch: 47 | Time: 0m 30s
# 	Train Loss: 1.393 | Train PPL:   4.028
# Epoch: 48 | Time: 0m 29s
# 	Train Loss: 1.394 | Train PPL:   4.032
# Epoch: 49 | Time: 0m 29s
# 	Train Loss: 1.340 | Train PPL:   3.819
# Epoch: 50 | Time: 0m 30s
# 	Train Loss: 1.302 | Train PPL:   3.677
# Epoch: 51 | Time: 0m 30s
# 	Train Loss: 1.333 | Train PPL:   3.792
# Epoch: 52 | Time: 0m 30s
# 	Train Loss: 1.306 | Train PPL:   3.692
# Epoch: 53 | Time: 0m 30s
# 	Train Loss: 1.287 | Train PPL:   3.623
# Epoch: 54 | Time: 0m 30s
# 	Train Loss: 1.277 | Train PPL:   3.586
# Epoch: 55 | Time: 0m 30s
# 	Train Loss: 1.246 | Train PPL:   3.478
# Epoch: 56 | Time: 0m 30s
# 	Train Loss: 1.222 | Train PPL:   3.393
# Epoch: 57 | Time: 0m 29s
# 	Train Loss: 1.262 | Train PPL:   3.533
# Epoch: 58 | Time: 0m 30s
# 	Train Loss: 1.233 | Train PPL:   3.432
# Epoch: 59 | Time: 0m 29s
# 	Train Loss: 1.174 | Train PPL:   3.234
# Epoch: 60 | Time: 0m 29s
# 	Train Loss: 1.159 | Train PPL:   3.187
# Epoch: 61 | Time: 0m 30s
# 	Train Loss: 1.160 | Train PPL:   3.189
# Epoch: 62 | Time: 0m 30s
# 	Train Loss: 1.164 | Train PPL:   3.201
# Epoch: 63 | Time: 0m 30s
# 	Train Loss: 1.186 | Train PPL:   3.275
# Epoch: 64 | Time: 0m 30s
# 	Train Loss: 1.169 | Train PPL:   3.220
# Epoch: 65 | Time: 0m 30s
# 	Train Loss: 1.105 | Train PPL:   3.019
# Epoch: 66 | Time: 0m 30s
# 	Train Loss: 1.201 | Train PPL:   3.324
# Epoch: 67 | Time: 0m 30s
# 	Train Loss: 1.126 | Train PPL:   3.082
# Epoch: 68 | Time: 0m 30s
# 	Train Loss: 1.080 | Train PPL:   2.946
# Epoch: 69 | Time: 0m 29s
# 	Train Loss: 1.088 | Train PPL:   2.967
# Epoch: 70 | Time: 0m 29s
# 	Train Loss: 1.093 | Train PPL:   2.984
# Epoch: 71 | Time: 0m 29s
# 	Train Loss: 1.106 | Train PPL:   3.021
# Epoch: 72 | Time: 0m 30s
# 	Train Loss: 1.055 | Train PPL:   2.871
# Epoch: 73 | Time: 0m 30s
# 	Train Loss: 1.036 | Train PPL:   2.817
# Epoch: 74 | Time: 0m 30s
# 	Train Loss: 1.056 | Train PPL:   2.875
# Epoch: 75 | Time: 0m 30s
# 	Train Loss: 1.027 | Train PPL:   2.792
# Epoch: 76 | Time: 0m 30s
# 	Train Loss: 1.008 | Train PPL:   2.739
# Epoch: 77 | Time: 0m 30s
# 	Train Loss: 1.017 | Train PPL:   2.764
# Epoch: 78 | Time: 0m 29s
# 	Train Loss: 1.008 | Train PPL:   2.740
# Epoch: 79 | Time: 0m 29s
# 	Train Loss: 0.983 | Train PPL:   2.672
# Epoch: 80 | Time: 0m 29s
# 	Train Loss: 0.985 | Train PPL:   2.679
# Epoch: 81 | Time: 0m 29s
# 	Train Loss: 0.965 | Train PPL:   2.624
# Epoch: 82 | Time: 0m 30s
# 	Train Loss: 0.961 | Train PPL:   2.614
# Epoch: 83 | Time: 0m 30s
# 	Train Loss: 0.954 | Train PPL:   2.595
# Epoch: 84 | Time: 0m 30s
# 	Train Loss: 0.947 | Train PPL:   2.579
# Epoch: 85 | Time: 0m 30s
# 	Train Loss: 0.921 | Train PPL:   2.512
# Epoch: 86 | Time: 0m 30s
# 	Train Loss: 0.915 | Train PPL:   2.496
# Epoch: 87 | Time: 0m 30s
# 	Train Loss: 0.924 | Train PPL:   2.518
# Epoch: 88 | Time: 0m 30s
# 	Train Loss: 0.893 | Train PPL:   2.442
# Epoch: 89 | Time: 0m 30s
# 	Train Loss: 0.896 | Train PPL:   2.449
# Epoch: 90 | Time: 0m 29s
# 	Train Loss: 0.904 | Train PPL:   2.469
# Epoch: 91 | Time: 0m 29s
# 	Train Loss: 0.883 | Train PPL:   2.418
# Epoch: 92 | Time: 0m 29s
# 	Train Loss: 0.887 | Train PPL:   2.427
# Epoch: 93 | Time: 0m 30s
# 	Train Loss: 0.874 | Train PPL:   2.397
# Epoch: 94 | Time: 0m 30s
# 	Train Loss: 0.879 | Train PPL:   2.408
# Epoch: 95 | Time: 0m 30s
# 	Train Loss: 0.868 | Train PPL:   2.382
# Epoch: 96 | Time: 0m 30s
# 	Train Loss: 0.863 | Train PPL:   2.371
# Epoch: 97 | Time: 0m 29s
# 	Train Loss: 0.830 | Train PPL:   2.294
# Epoch: 98 | Time: 0m 29s
# 	Train Loss: 0.820 | Train PPL:   2.270
# Epoch: 99 | Time: 0m 30s
# 	Train Loss: 0.814 | Train PPL:   2.256
# Epoch: 100 | Time: 0m 29s
# 	Train Loss: 0.822 | Train PPL:   2.275
# Epoch: 101 | Time: 0m 29s
# 	Train Loss: 0.797 | Train PPL:   2.219
# Epoch: 102 | Time: 0m 29s
# 	Train Loss: 0.784 | Train PPL:   2.191
# Epoch: 103 | Time: 0m 30s
# 	Train Loss: 0.799 | Train PPL:   2.223
# Epoch: 104 | Time: 0m 30s
# 	Train Loss: 0.795 | Train PPL:   2.215
# Epoch: 105 | Time: 0m 30s
# 	Train Loss: 0.782 | Train PPL:   2.185
# Epoch: 106 | Time: 0m 30s
# 	Train Loss: 0.771 | Train PPL:   2.161
# Epoch: 107 | Time: 0m 30s
# 	Train Loss: 0.763 | Train PPL:   2.145
# Epoch: 108 | Time: 0m 30s
# 	Train Loss: 0.751 | Train PPL:   2.118
# Epoch: 109 | Time: 0m 29s
# 	Train Loss: 0.749 | Train PPL:   2.116
# Epoch: 110 | Time: 0m 30s
# 	Train Loss: 0.732 | Train PPL:   2.080
# Epoch: 111 | Time: 0m 30s
# 	Train Loss: 0.724 | Train PPL:   2.064
# Epoch: 112 | Time: 0m 29s
# 	Train Loss: 0.738 | Train PPL:   2.091
# Epoch: 113 | Time: 0m 29s
# 	Train Loss: 0.718 | Train PPL:   2.051
# Epoch: 114 | Time: 0m 30s
# 	Train Loss: 0.719 | Train PPL:   2.053
# Epoch: 115 | Time: 0m 30s
# 	Train Loss: 0.705 | Train PPL:   2.025
# Epoch: 116 | Time: 0m 30s
# 	Train Loss: 0.710 | Train PPL:   2.034
# Epoch: 117 | Time: 0m 30s
# 	Train Loss: 0.696 | Train PPL:   2.005
# Epoch: 118 | Time: 0m 29s
# 	Train Loss: 0.688 | Train PPL:   1.989
# Epoch: 119 | Time: 0m 30s
# 	Train Loss: 0.703 | Train PPL:   2.019
# Epoch: 120 | Time: 0m 29s
# 	Train Loss: 0.685 | Train PPL:   1.984
# Epoch: 121 | Time: 0m 30s
# 	Train Loss: 0.696 | Train PPL:   2.006
# Epoch: 122 | Time: 0m 30s
# 	Train Loss: 0.689 | Train PPL:   1.992
# Epoch: 123 | Time: 0m 29s
# 	Train Loss: 0.661 | Train PPL:   1.937
# Epoch: 124 | Time: 0m 29s
# 	Train Loss: 0.658 | Train PPL:   1.932
# Epoch: 125 | Time: 0m 29s
# 	Train Loss: 0.662 | Train PPL:   1.938
# Epoch: 126 | Time: 0m 30s
# 	Train Loss: 0.635 | Train PPL:   1.887
# Epoch: 127 | Time: 0m 30s
# 	Train Loss: 0.626 | Train PPL:   1.869
# Epoch: 128 | Time: 0m 30s
# 	Train Loss: 0.611 | Train PPL:   1.841
# Epoch: 129 | Time: 0m 30s
# 	Train Loss: 0.626 | Train PPL:   1.871
# Epoch: 130 | Time: 0m 30s
# 	Train Loss: 0.624 | Train PPL:   1.866
# Epoch: 131 | Time: 0m 30s
# 	Train Loss: 0.627 | Train PPL:   1.872
# Epoch: 132 | Time: 0m 30s
# 	Train Loss: 0.644 | Train PPL:   1.903
# Epoch: 133 | Time: 0m 29s
# 	Train Loss: 0.644 | Train PPL:   1.905
# Epoch: 134 | Time: 0m 29s
# 	Train Loss: 0.605 | Train PPL:   1.831
# Epoch: 135 | Time: 0m 29s
# 	Train Loss: 0.611 | Train PPL:   1.843
# Epoch: 136 | Time: 0m 30s
# 	Train Loss: 0.633 | Train PPL:   1.883
# Epoch: 137 | Time: 0m 30s
# 	Train Loss: 0.603 | Train PPL:   1.828
# Epoch: 138 | Time: 0m 30s
# 	Train Loss: 0.594 | Train PPL:   1.812
# Epoch: 139 | Time: 0m 30s
# 	Train Loss: 0.587 | Train PPL:   1.799
# Epoch: 140 | Time: 0m 30s
# 	Train Loss: 0.579 | Train PPL:   1.785
# Epoch: 141 | Time: 0m 30s
# 	Train Loss: 0.592 | Train PPL:   1.808
# Epoch: 142 | Time: 0m 30s
# 	Train Loss: 0.581 | Train PPL:   1.787
# Epoch: 143 | Time: 0m 30s
# 	Train Loss: 0.578 | Train PPL:   1.782
# Epoch: 144 | Time: 0m 29s
# 	Train Loss: 0.580 | Train PPL:   1.785
# Epoch: 145 | Time: 0m 29s
# 	Train Loss: 0.582 | Train PPL:   1.790
# Epoch: 146 | Time: 0m 29s
# 	Train Loss: 0.556 | Train PPL:   1.743
# Epoch: 147 | Time: 0m 29s
# 	Train Loss: 0.558 | Train PPL:   1.747
# Epoch: 148 | Time: 0m 30s
# 	Train Loss: 0.544 | Train PPL:   1.723
# Epoch: 149 | Time: 0m 30s
# 	Train Loss: 0.547 | Train PPL:   1.727
# Epoch: 150 | Time: 0m 29s
# 	Train Loss: 0.553 | Train PPL:   1.738
# Epoch: 151 | Time: 0m 30s
# 	Train Loss: 0.532 | Train PPL:   1.703
# Epoch: 152 | Time: 0m 30s
# 	Train Loss: 0.537 | Train PPL:   1.710
# Epoch: 153 | Time: 0m 30s
# 	Train Loss: 0.523 | Train PPL:   1.687
# Epoch: 154 | Time: 0m 30s
# 	Train Loss: 0.516 | Train PPL:   1.676
# Epoch: 155 | Time: 0m 30s
# 	Train Loss: 0.524 | Train PPL:   1.689
# Epoch: 156 | Time: 0m 29s
# 	Train Loss: 0.522 | Train PPL:   1.685
# Epoch: 157 | Time: 0m 29s
# 	Train Loss: 0.528 | Train PPL:   1.696
# Epoch: 158 | Time: 0m 30s
# 	Train Loss: 0.526 | Train PPL:   1.693
# Epoch: 159 | Time: 0m 30s
# 	Train Loss: 0.529 | Train PPL:   1.697
# Epoch: 160 | Time: 0m 30s
# 	Train Loss: 0.506 | Train PPL:   1.658
# Epoch: 161 | Time: 0m 30s
# 	Train Loss: 0.501 | Train PPL:   1.650
# Epoch: 162 | Time: 0m 30s
# 	Train Loss: 0.497 | Train PPL:   1.644
# Epoch: 163 | Time: 0m 30s
# 	Train Loss: 0.497 | Train PPL:   1.643
# Epoch: 164 | Time: 0m 29s
# 	Train Loss: 0.488 | Train PPL:   1.629
# Epoch: 165 | Time: 0m 30s
# 	Train Loss: 0.494 | Train PPL:   1.639
# Epoch: 166 | Time: 0m 30s
# 	Train Loss: 0.489 | Train PPL:   1.631
# Epoch: 167 | Time: 0m 29s
# 	Train Loss: 0.506 | Train PPL:   1.659
# Epoch: 168 | Time: 0m 29s
# 	Train Loss: 0.500 | Train PPL:   1.649
# Epoch: 169 | Time: 0m 30s
# 	Train Loss: 0.499 | Train PPL:   1.648
# Epoch: 170 | Time: 0m 30s
# 	Train Loss: 0.489 | Train PPL:   1.631
# Epoch: 171 | Time: 0m 29s
# 	Train Loss: 0.489 | Train PPL:   1.631
# Epoch: 172 | Time: 0m 30s
# 	Train Loss: 0.482 | Train PPL:   1.620
# Epoch: 173 | Time: 0m 30s
# 	Train Loss: 0.485 | Train PPL:   1.624
# Epoch: 174 | Time: 0m 30s
# 	Train Loss: 0.488 | Train PPL:   1.630
# Epoch: 175 | Time: 0m 30s
# 	Train Loss: 0.489 | Train PPL:   1.631
# Epoch: 176 | Time: 0m 30s
# 	Train Loss: 0.479 | Train PPL:   1.615
# Epoch: 177 | Time: 0m 30s
# 	Train Loss: 0.481 | Train PPL:   1.617
# Epoch: 178 | Time: 0m 29s
# 	Train Loss: 0.475 | Train PPL:   1.608
# Epoch: 179 | Time: 0m 29s
# 	Train Loss: 0.468 | Train PPL:   1.597
# Epoch: 180 | Time: 0m 30s
# 	Train Loss: 0.465 | Train PPL:   1.592
# Epoch: 181 | Time: 0m 30s
# 	Train Loss: 0.461 | Train PPL:   1.585
# Epoch: 182 | Time: 0m 30s
# 	Train Loss: 0.461 | Train PPL:   1.586
# Epoch: 183 | Time: 0m 30s
# 	Train Loss: 0.471 | Train PPL:   1.601
# Epoch: 184 | Time: 0m 30s
# 	Train Loss: 0.457 | Train PPL:   1.579
# Epoch: 185 | Time: 0m 30s
# 	Train Loss: 0.443 | Train PPL:   1.558
# Epoch: 186 | Time: 0m 30s
# 	Train Loss: 0.453 | Train PPL:   1.573
# Epoch: 187 | Time: 0m 30s
# 	Train Loss: 0.448 | Train PPL:   1.565
# Epoch: 188 | Time: 0m 29s
# 	Train Loss: 0.450 | Train PPL:   1.569
# Epoch: 189 | Time: 0m 29s
# 	Train Loss: 0.451 | Train PPL:   1.570
# Epoch: 190 | Time: 0m 29s
# 	Train Loss: 0.454 | Train PPL:   1.575
# Epoch: 191 | Time: 0m 30s
# 	Train Loss: 0.447 | Train PPL:   1.564
# Epoch: 192 | Time: 0m 30s
# 	Train Loss: 0.444 | Train PPL:   1.559
# Epoch: 193 | Time: 0m 30s
# 	Train Loss: 0.448 | Train PPL:   1.565
# Epoch: 194 | Time: 0m 30s
# 	Train Loss: 0.441 | Train PPL:   1.554
# Epoch: 195 | Time: 0m 30s
# 	Train Loss: 0.438 | Train PPL:   1.549
# Epoch: 196 | Time: 0m 30s
# 	Train Loss: 0.442 | Train PPL:   1.556
# Epoch: 197 | Time: 0m 30s
# 	Train Loss: 0.433 | Train PPL:   1.542
# Epoch: 198 | Time: 0m 30s
# 	Train Loss: 0.461 | Train PPL:   1.586
# Epoch: 199 | Time: 0m 29s
# 	Train Loss: 0.445 | Train PPL:   1.561
# Epoch: 200 | Time: 0m 29s
# 	Train Loss: 0.428 | Train PPL:   1.535
# Epoch: 201 | Time: 0m 29s
# 	Train Loss: 0.441 | Train PPL:   1.554
# Epoch: 202 | Time: 0m 30s
# 	Train Loss: 0.436 | Train PPL:   1.546
# Epoch: 203 | Time: 0m 30s
# 	Train Loss: 0.423 | Train PPL:   1.527
# Epoch: 204 | Time: 0m 30s
# 	Train Loss: 0.420 | Train PPL:   1.523
# Epoch: 205 | Time: 0m 30s
# 	Train Loss: 0.432 | Train PPL:   1.541
# Epoch: 206 | Time: 0m 30s
# 	Train Loss: 0.428 | Train PPL:   1.534
# Epoch: 207 | Time: 0m 30s
# 	Train Loss: 0.432 | Train PPL:   1.540
# Epoch: 208 | Time: 0m 30s
# 	Train Loss: 0.427 | Train PPL:   1.533
# Epoch: 209 | Time: 0m 30s
# 	Train Loss: 0.426 | Train PPL:   1.531
# Epoch: 210 | Time: 0m 30s
# 	Train Loss: 0.425 | Train PPL:   1.530
# Epoch: 211 | Time: 0m 30s
# 	Train Loss: 0.422 | Train PPL:   1.525
# Epoch: 212 | Time: 0m 30s
# 	Train Loss: 0.418 | Train PPL:   1.520
# Epoch: 213 | Time: 0m 30s
# 	Train Loss: 0.424 | Train PPL:   1.529
# Epoch: 214 | Time: 0m 30s
# 	Train Loss: 0.427 | Train PPL:   1.532
# Epoch: 215 | Time: 0m 30s
# 	Train Loss: 0.420 | Train PPL:   1.522
# Epoch: 216 | Time: 0m 30s
# 	Train Loss: 0.424 | Train PPL:   1.528
# Epoch: 217 | Time: 0m 30s
# 	Train Loss: 0.413 | Train PPL:   1.512
# Epoch: 218 | Time: 0m 30s
# 	Train Loss: 0.410 | Train PPL:   1.507
# Epoch: 219 | Time: 0m 30s
# 	Train Loss: 0.405 | Train PPL:   1.499
# Epoch: 220 | Time: 0m 30s
# 	Train Loss: 0.400 | Train PPL:   1.492
# Epoch: 221 | Time: 0m 30s
# 	Train Loss: 0.412 | Train PPL:   1.510
# Epoch: 222 | Time: 0m 30s
# 	Train Loss: 0.399 | Train PPL:   1.490
# Epoch: 223 | Time: 0m 30s
# 	Train Loss: 0.405 | Train PPL:   1.500
# Epoch: 224 | Time: 0m 30s
# 	Train Loss: 0.398 | Train PPL:   1.488
# Epoch: 225 | Time: 0m 30s
# 	Train Loss: 0.400 | Train PPL:   1.492
# Epoch: 226 | Time: 0m 30s
# 	Train Loss: 0.405 | Train PPL:   1.499
# Epoch: 227 | Time: 0m 30s
# 	Train Loss: 0.407 | Train PPL:   1.502
# Epoch: 228 | Time: 0m 30s
# 	Train Loss: 0.409 | Train PPL:   1.506
# Epoch: 229 | Time: 0m 30s
# 	Train Loss: 0.397 | Train PPL:   1.488
# Epoch: 230 | Time: 0m 30s
# 	Train Loss: 0.392 | Train PPL:   1.481
# Epoch: 231 | Time: 0m 30s
# 	Train Loss: 0.401 | Train PPL:   1.493
# Epoch: 232 | Time: 0m 30s
# 	Train Loss: 0.394 | Train PPL:   1.483
# Epoch: 233 | Time: 0m 30s
# 	Train Loss: 0.396 | Train PPL:   1.486
# Epoch: 234 | Time: 0m 30s
# 	Train Loss: 0.394 | Train PPL:   1.483
# Epoch: 235 | Time: 0m 30s
# 	Train Loss: 0.393 | Train PPL:   1.482
# Epoch: 236 | Time: 0m 30s
# 	Train Loss: 0.383 | Train PPL:   1.466
# Epoch: 237 | Time: 0m 30s
# 	Train Loss: 0.386 | Train PPL:   1.471
# Epoch: 238 | Time: 0m 30s
# 	Train Loss: 0.391 | Train PPL:   1.479
# Epoch: 239 | Time: 0m 30s
# 	Train Loss: 0.387 | Train PPL:   1.473
# Epoch: 240 | Time: 0m 30s
# 	Train Loss: 0.384 | Train PPL:   1.468
# Epoch: 241 | Time: 0m 30s
# 	Train Loss: 0.383 | Train PPL:   1.466
# Epoch: 242 | Time: 0m 30s
# 	Train Loss: 0.380 | Train PPL:   1.462
# Epoch: 243 | Time: 0m 30s
# 	Train Loss: 0.379 | Train PPL:   1.461
# Epoch: 244 | Time: 0m 30s
# 	Train Loss: 0.384 | Train PPL:   1.468
# Epoch: 245 | Time: 0m 30s
# 	Train Loss: 0.381 | Train PPL:   1.464
# Epoch: 246 | Time: 0m 30s
# 	Train Loss: 0.376 | Train PPL:   1.456
# Epoch: 247 | Time: 0m 30s
# 	Train Loss: 0.379 | Train PPL:   1.460
# Epoch: 248 | Time: 0m 30s
# 	Train Loss: 0.378 | Train PPL:   1.460
# Epoch: 249 | Time: 0m 30s
# 	Train Loss: 0.373 | Train PPL:   1.453
# Epoch: 250 | Time: 0m 30s
# 	Train Loss: 0.372 | Train PPL:   1.451
# Epoch: 251 | Time: 0m 30s
# 	Train Loss: 0.378 | Train PPL:   1.459
# Epoch: 252 | Time: 0m 30s
# 	Train Loss: 0.381 | Train PPL:   1.464
# Epoch: 253 | Time: 0m 30s
# 	Train Loss: 0.380 | Train PPL:   1.462
# Epoch: 254 | Time: 0m 30s
# 	Train Loss: 0.377 | Train PPL:   1.458
# Epoch: 255 | Time: 0m 30s
# 	Train Loss: 0.387 | Train PPL:   1.473
# Epoch: 256 | Time: 0m 30s
# 	Train Loss: 0.387 | Train PPL:   1.472
# Epoch: 257 | Time: 0m 30s
# 	Train Loss: 0.379 | Train PPL:   1.461
# Epoch: 258 | Time: 0m 30s
# 	Train Loss: 0.373 | Train PPL:   1.452
# Epoch: 259 | Time: 0m 30s
# 	Train Loss: 0.378 | Train PPL:   1.460
# Epoch: 260 | Time: 0m 30s
# 	Train Loss: 0.374 | Train PPL:   1.454
# Epoch: 261 | Time: 0m 30s
# 	Train Loss: 0.379 | Train PPL:   1.460
# Epoch: 262 | Time: 0m 30s
# 	Train Loss: 0.379 | Train PPL:   1.461
# Epoch: 263 | Time: 0m 30s
# 	Train Loss: 0.372 | Train PPL:   1.451
# Epoch: 264 | Time: 0m 30s
# 	Train Loss: 0.373 | Train PPL:   1.453
# Epoch: 265 | Time: 0m 30s
# 	Train Loss: 0.367 | Train PPL:   1.444
# Epoch: 266 | Time: 0m 30s
# 	Train Loss: 0.363 | Train PPL:   1.437
# Epoch: 267 | Time: 0m 30s
# 	Train Loss: 0.368 | Train PPL:   1.445
# Epoch: 268 | Time: 0m 30s
# 	Train Loss: 0.362 | Train PPL:   1.436
# Epoch: 269 | Time: 0m 30s
# 	Train Loss: 0.360 | Train PPL:   1.433
# Epoch: 270 | Time: 0m 30s
# 	Train Loss: 0.367 | Train PPL:   1.443
# Epoch: 271 | Time: 0m 30s
# 	Train Loss: 0.373 | Train PPL:   1.452
# Epoch: 272 | Time: 0m 30s
# 	Train Loss: 0.365 | Train PPL:   1.441
# Epoch: 273 | Time: 0m 30s
# 	Train Loss: 0.366 | Train PPL:   1.442
# Epoch: 274 | Time: 0m 30s
# 	Train Loss: 0.364 | Train PPL:   1.439
# Epoch: 275 | Time: 0m 30s
# 	Train Loss: 0.366 | Train PPL:   1.442
# Epoch: 276 | Time: 0m 30s
# 	Train Loss: 0.372 | Train PPL:   1.451
# Epoch: 277 | Time: 0m 30s
# 	Train Loss: 0.370 | Train PPL:   1.448
# Epoch: 278 | Time: 0m 30s
# 	Train Loss: 0.356 | Train PPL:   1.428
# Epoch: 279 | Time: 0m 30s
# 	Train Loss: 0.353 | Train PPL:   1.423
# Epoch: 280 | Time: 0m 30s
# 	Train Loss: 0.360 | Train PPL:   1.433
# Epoch: 281 | Time: 0m 30s
# 	Train Loss: 0.358 | Train PPL:   1.431
# Epoch: 282 | Time: 0m 30s
# 	Train Loss: 0.359 | Train PPL:   1.432
# Epoch: 283 | Time: 0m 30s
# 	Train Loss: 0.351 | Train PPL:   1.421
# Epoch: 284 | Time: 0m 30s
# 	Train Loss: 0.348 | Train PPL:   1.416
# Epoch: 285 | Time: 0m 30s
# 	Train Loss: 0.351 | Train PPL:   1.421
# Epoch: 286 | Time: 0m 30s
# 	Train Loss: 0.349 | Train PPL:   1.418
# Epoch: 287 | Time: 0m 30s
# 	Train Loss: 0.354 | Train PPL:   1.424
# Epoch: 288 | Time: 0m 30s
# 	Train Loss: 0.357 | Train PPL:   1.429
# Epoch: 289 | Time: 0m 30s
# 	Train Loss: 0.357 | Train PPL:   1.429
# Epoch: 290 | Time: 0m 30s
# 	Train Loss: 0.353 | Train PPL:   1.423
# Epoch: 291 | Time: 0m 30s
# 	Train Loss: 0.357 | Train PPL:   1.428
# Epoch: 292 | Time: 0m 30s
# 	Train Loss: 0.354 | Train PPL:   1.425
# Epoch: 293 | Time: 0m 30s
# 	Train Loss: 0.352 | Train PPL:   1.421
# Epoch: 294 | Time: 0m 30s
# 	Train Loss: 0.350 | Train PPL:   1.419
# Epoch: 295 | Time: 0m 30s
# 	Train Loss: 0.348 | Train PPL:   1.416
# Epoch: 296 | Time: 0m 30s
# 	Train Loss: 0.349 | Train PPL:   1.418
# Epoch: 297 | Time: 0m 30s
# 	Train Loss: 0.347 | Train PPL:   1.414
# Epoch: 298 | Time: 0m 30s
# 	Train Loss: 0.343 | Train PPL:   1.410
# Epoch: 299 | Time: 0m 30s
# 	Train Loss: 0.349 | Train PPL:   1.417
# Epoch: 300 | Time: 0m 30s
# 	Train Loss: 0.346 | Train PPL:   1.414

# %%
torch.save(model.state_dict(), "model-5.pt")

# %%
source_sentence = ["<sos>"] + train_dataset[1500].query + ["<eos>"]
#source_sentence = ["<sos>"] + ["are","you","batman","?"] + ["<eos>"]
target_sentence = ["<sos>"] + train_dataset[1500].response + ["<eos>"]
print(' '.join(source_sentence))
print(' '.join(target_sentence))
# Out:
# <sos> bye mom . <eos>
# <sos> we was robbed . <eos>

# %%
x = SRC.numericalize([source_sentence]).to(device)
# y = TRG.numericalize([target_sentence]).to(device)
# We actually do not have y in real world, translation should only
# rely on source data. translate_sequences should work worse than
# model(x, y), as it uses its own predicted tokens rather than
# tokens from gold example (y).
translation = model.translate_sequences(x)
translation = translation[0].cpu().detach().numpy()

print(translation)
for x in translation[1:]:
    word = TRG.vocab.itos[x]
    if word == "<eos>":
        break
    print(word, end=' ')
    #print(x)
# Out:
# [   2   27   35 2737    4    3    3    3    3    3    3    3    3    3
#     3    3    3    3    3    3    3    3    3    3    3    3    3    3
#     3    3    3    3    3    3    3    3    3    3    3    3    3    3
#     3    3    3    3    3    3    3    3    3]
# we was robbed .

# %%
for i in range(10000,10030):
  print("\n"+"**"*10)
  source_sentence = ["<sos>"] + train_dataset[i].query + ["<eos>"]
  target_sentence = ["<sos>"] + train_dataset[i].response + ["<eos>"]
  print(' '.join(source_sentence))
  print(' '.join(target_sentence))
  x = SRC.numericalize([source_sentence]).to(device)
  # y = TRG.numericalize([target_sentence]).to(device)
  # We actually do not have y in real world, translation should only
  # rely on source data. translate_sequences should work worse than
  # model(x, y), as it uses its own predicted tokens rather than
  # tokens from gold example (y).
  translation = model.translate_sequences(x)
  translation = translation[0].cpu().detach().numpy()
  for x in translation[1:]:
      word = TRG.vocab.itos[x]
      if word == "<eos>":
          break
      print(word, end=' ')
# Out:
# ********************
# <sos> about what ? <eos>
# <sos> about the accident . <eos>
# about the accident .
# ********************
# <sos> what kind of trouble . <eos>
# <sos> you tell me . <eos>
# you tell me .
# ********************
# <sos> you tell me . <eos>
# <sos> i ca n't . <eos>
# do you fear them ?
# ********************
# <sos> no . <eos>
# <sos> anything at all ? <eos>
# why not ?
# ********************
# <sos> anything at all ? <eos>
# <sos> no , sir . <eos>
# no , sir .
# ********************
# <sos> no , sir . <eos>
# <sos> was he with anyone ? <eos>
# how about miss flintstone ?
# ********************
# <sos> to buy lingerie . <eos>
# <sos> for your wife ? <eos>
# for your wife ?
# ********************
# <sos> uh - oh . <eos>
# <sos> listen to him . <eos>
# what ? !
# ********************
# <sos> something bad happened tonight . <eos>
# <sos> what ? <eos>
# what ?
# ********************
# <sos> bobby ? <eos>
# <sos> yeah . <eos>
# yeah .
# ********************
# <sos> no . <eos>
# <sos> sorry . <eos>
# why ?
# ********************
# <sos> sorry . <eos>
# <sos> it 's okay . <eos>
# it 's okay .
# ********************
# <sos> robert-- <eos>
# <sos> it 's not true . <eos>
# it 's not true .
# ********************
# <sos> stacy-- <eos>
# <sos> leave this house . <eos>
# leave this house .
# ********************
# <sos> is eric in school ? <eos>
# <sos> yes . <eos>
# yes .
# ********************
# <sos> does that hurt ? <eos>
# <sos> well ... yeah . <eos>
# no !
# ********************
# <sos> well ... yeah . <eos>
# <sos> good . <eos>
# good .
# ********************
# <sos> good . <eos>
# <sos> stacy-- <eos>
# thanks .
# ********************
# <sos> you opened the thing ? <eos>
# <sos> the lingerie . <eos>
# the lingerie .
# ********************
# <sos> the lingerie . <eos>
# <sos> that was for christmas . <eos>
# that was for christmas .
# ********************
# <sos> that was for christmas . <eos>
# <sos> i was missing you . <eos>
# i was missing you .
# ********************
# <sos> what is it ? <eos>
# <sos> oh christ . <eos>
# the sheets ...
# ********************
# <sos> is it over ? <eos>
# <sos> it 's over . <eos>
# not quite ....
# ********************
# <sos> my suitcase-- <eos>
# <sos> sir ? <eos>
# sir ?
# ********************
# <sos> sir ? <eos>
# <sos> my suitcase is gone . <eos>
# you better take this .
# ********************
# <sos> that ai n't me . <eos>
# <sos> it 's not ? <eos>
# it 's not ?
# ********************
# <sos> how 's the trout ? <eos>
# <sos> it tastes like fish . <eos>
# it tastes like fish .
# ********************
# <sos> it tastes like fish . <eos>
# <sos> it is fish . <eos>
# it is fish .
# ********************
# <sos> do you like fish ? <eos>
# <sos> not that much . <eos>
# not that much .
# ********************
# <sos> depinto ? <eos>
# <sos> brill . <eos>
# brill .
